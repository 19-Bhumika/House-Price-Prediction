# %% [markdown]
# # SECTION 1

# %% [markdown]
# ## Objectives
# The attached dataset has rent details of some houses in Lavasa.<br>
#
# Common Instructions<br>
# Use Pandas to Import the Dataset<br>
# Do the necessary Exploratory Data Analysis<br>
# Use the train_test_split method available in SCIKIT to split the dataset into Train Dataset and Test Dataset.<br>
# Show the Regression Score, Intercept and other parameters etc in the Output
# Use visualizations and plots wherever possible<br>
# Format the outputs neatly; Do Documentation, Data Set Description, Objectives, Observations, Conclusions etc as you have done in your previous lab<br>
# Questions<br>
# 1. What are your observations on the Dataset?
# 2. What are the different Error Measures (Evaluation Metrics) in relation to Linear Regression? How much do you get in the above cases?
# 3. Note down the errors/losses when the train-test ratio is 50:50, 60:40, 70:30, and 80:20
# 4. During LinearRegression() process, what is the impact of giving TRUE/FALSE as the value for Normalize Parameter?
#
# Cases<br>
# Try to predict the rent of the below houses -<br>
# 1. 1 BHK with 2 Baths in Portofino Street
# 2. Fully Furnished 2 BHK in School Street
# 3. Single Room anywhere in Lavasa

# %% [markdown]
# ## Problem Definition
# For above mentioned objectives, we have to basically predict the house rent of Lavasa based on certain features which are given in the dataframe.

# %% [markdown]
# ## Approach
# Jupyter Notebook is used for the succesful execution of this Lab 3!
#
# Approach which I followed is as follows:
#
# 1. Identified various requirements of the lab as per sections.
# 2. Went through sections of this Lab to understand its purpose and detailed idea of executing models to satisfy the needs of the questions:
#
#     -->1. The <b>first section</b> consists of Lab-Overview part with objectives and problem definition, followed by approach and then other sections of the lab which includes execution.
#
#     -->2. The <b>second section</b> consists of the execution of the common instructions.
#
#     -->3. <b>Third section</b> contains the answers of the questions which are being provided in the lab.
#
#     -->4. <b>Fourth section</b> consists of the cases part in which prediction based on user input is taken into consideration to predict the house rent of Lavasa.
#
#     -->5. <b>Fifth section</b> consists of conlcusion.
#
#     -->6. <b>Sixed section</b> states reference links used throughout the lab.

# %% [markdown]
# # SECTION 2

# %% [markdown]
# ## Use Pandas to Import the Dataset.

# %%
import pandas as pd
df=pd.read_csv("HousePrices - Lab3.csv")

# %%
df
# Out:
#               BuildingType       Location   Size  AreaSqFt  NoOfBath  \
# 0     Minimum Budget Rooms    Portofino H  1 BHK     400.0         1
# 1     Minimum Budget Rooms    Portofino H  1 BHK     450.0         1
# 2     Minimum Budget Rooms  School Street  1 BHK     530.0         1
# 3     Minimum Budget Rooms    Portofino B  1 BHK     400.0         1
# 4     Minimum Budget Rooms  School Street  2 BHK     460.0         1
# ..                     ...            ...    ...       ...       ...
# 995  Super Furnished Villa    Portofino D  4 BHK    4900.0         4
# 996  Super Furnished Villa    Portofino B  4 BHK    3750.0         4
# 997  Super Furnished Villa  School Street  4 BHK    5270.0         4
# 998  Super Furnished Villa    Portofino B  6 BHK    5100.0         7
# 999  Super Furnished Villa    Portofino B  7 BHK    6300.0         6
#
#      NoOfPeople  NoOfBalcony  RentPerMonth
# 0             1            1        1100.0
# 1             1            1        1100.0
# ...

# %% [markdown]
# # -->Do the necessary Exploratory Data Analysis
# # -->Use visualizations and plots wherever possible

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.size
# Out:
# 8000

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               BuildingType       Location   Size  AreaSqFt  NoOfBath  \
# 0     Minimum Budget Rooms    Portofino H  1 BHK     400.0         1
# 1     Minimum Budget Rooms    Portofino H  1 BHK     450.0         1
# 2     Minimum Budget Rooms  School Street  1 BHK     530.0         1
# 3     Minimum Budget Rooms    Portofino B  1 BHK     400.0         1
# 4     Minimum Budget Rooms  School Street  2 BHK     460.0         1
# ..                     ...            ...    ...       ...       ...
# 995  Super Furnished Villa    Portofino D  4 BHK    4900.0         4
# 996  Super Furnished Villa    Portofino B  4 BHK    3750.0         4
# 997  Super Furnished Villa  School Street  4 BHK    5270.0         4
# 998  Super Furnished Villa    Portofino B  6 BHK    5100.0         7
# 999  Super Furnished Villa    Portofino B  7 BHK    6300.0         6
#
#      NoOfPeople  NoOfBalcony  RentPerMonth
# 0             1            1        1100.0
# ...

# %%
df.head()
# Out:
#            BuildingType       Location   Size  AreaSqFt  NoOfBath  NoOfPeople  \
# 0  Minimum Budget Rooms    Portofino H  1 BHK     400.0         1           1
# 1  Minimum Budget Rooms    Portofino H  1 BHK     450.0         1           1
# 2  Minimum Budget Rooms  School Street  1 BHK     530.0         1           1
# 3  Minimum Budget Rooms    Portofino B  1 BHK     400.0         1           1
# 4  Minimum Budget Rooms  School Street  2 BHK     460.0         1           1
#
#    NoOfBalcony  RentPerMonth
# 0            1        1100.0
# 1            1        1100.0
# 2            0        1166.0
# 3            0        1400.0
# 4            0        1500.0

# %%
df.tail()
# Out:
#               BuildingType       Location   Size  AreaSqFt  NoOfBath  \
# 995  Super Furnished Villa    Portofino D  4 BHK    4900.0         4
# 996  Super Furnished Villa    Portofino B  4 BHK    3750.0         4
# 997  Super Furnished Villa  School Street  4 BHK    5270.0         4
# 998  Super Furnished Villa    Portofino B  6 BHK    5100.0         7
# 999  Super Furnished Villa    Portofino B  7 BHK    6300.0         6
#
#      NoOfPeople  NoOfBalcony  RentPerMonth
# 995           6            3       70000.0
# 996           5            0       76000.0
# 997           5            3       80000.0
# 998           6            3       90000.0
# 999           6            3       96000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BuildingType  1000 non-null   object
#  1   Location      1000 non-null   object
#  2   Size          1000 non-null   object
#  3   AreaSqFt      1000 non-null   float64
#  4   NoOfBath      1000 non-null   int64
#  5   NoOfPeople    1000 non-null   int64
#  6   NoOfBalcony   1000 non-null   int64
#  7   RentPerMonth  1000 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 62.6+ KB

# %%
#Find the sum of the duplicates from the dataset.
df.duplicated().sum()
# Out:
# 6

# %%
#Find null values
df.isnull().sum()
# Out:
# BuildingType    0
# Location        0
# Size            0
# AreaSqFt        0
# NoOfBath        0
# NoOfPeople      0
# NoOfBalcony     0
# RentPerMonth    0
# dtype: int64

# %%
#Know the Datatypes
df.dtypes
# Out:
# BuildingType     object
# Location         object
# Size             object
# AreaSqFt        float64
# NoOfBath          int64
# NoOfPeople        int64
# NoOfBalcony       int64
# RentPerMonth    float64
# dtype: object

# %%
#To find correlation between all the variables
df.corr()
# Out:
#               AreaSqFt  NoOfBath  NoOfPeople  NoOfBalcony  RentPerMonth
# AreaSqFt      1.000000  0.375791    0.374907     0.206123      0.473022
# NoOfBath      0.375791  1.000000    0.480063     0.258885      0.579693
# NoOfPeople    0.374907  0.480063    1.000000     0.184932      0.782853
# NoOfBalcony   0.206123  0.258885    0.184932     1.000000      0.193619
# RentPerMonth  0.473022  0.579693    0.782853     0.193619      1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.describe().plot(kind = "area",fontsize=27, figsize = (20,8), table = True,colormap="gnuplot_r")
plt.xlabel('Statistics',)
plt.ylabel('Value')
plt.title("General Statistics of Dataset")
# Out:
# Text(0.5, 1.0, 'General Statistics of Dataset')

# %% [markdown]
# ## DistPlot

# %%
cfn=df['NoOfPeople'].dropna()
sns.distplot(cfn,color="#ff0040")         
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## JointPlot

# %%
sns.jointplot("NoOfBath", "NoOfPeople", data=df, kind='reg',space=0,color='#008080')
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## PairPlot

# %%
sns.set_style("dark")
sns.pairplot(df,hue="Location",height=3,palette="icefire")
plt.show()

# %% [markdown]
# ## RugPlot

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.rugplot(data = df, x = "NoOfBath",palette="Spectral")
plt.subplot(2,2,2)
sns.rugplot(data = df, x = "NoOfPeople",palette="coolwarm")
plt.subplot(2,2,3)
sns.rugplot(data = df, x = "NoOfBalcony",palette="vlag")
plt.subplot(2,2,4)
sns.rugplot(data = df, x = "AreaSqFt",palette="dark:salmon_r")
# Out:
# <AxesSubplot:xlabel='AreaSqFt'>

# %% [markdown]
# ## CatPlot

# %%
sns.catplot(x='AreaSqFt',y='Location', jitter=True, data=df,palette="Spectral",orient='h')

# %% [markdown]
# ## BarPlot

# %%
sns.set_theme(style="ticks")
ax = sns.barplot(x="AreaSqFt", y="Location", data=df,palette="coolwarm",orient='h')

# %% [markdown]
# ## BoxPlot

# %%
ax = sns.boxplot(x="AreaSqFt", y="NoOfBalcony", hue="Location",
                 data=df, palette="Set3",orient='h')

# %%
ax = sns.boxplot(x="NoOfPeople", y="Location", hue="Location",
                 data=df, palette="afmhot",orient='h')

# %%
ax = sns.boxplot(x="NoOfBath", y="BuildingType", hue="Location",
                 data=df, palette="flag_r",orient='h')

# %%
ax = sns.boxplot(x="NoOfPeople", y="BuildingType", hue="Location",
                 data=df, palette="gist_rainbow",orient='h')

# %% [markdown]
# ## CountPlot

# %%
ax = sns.countplot(y="BuildingType", hue="BuildingType", data=df,orient='h',palette="icefire")

# %% [markdown]
# ## Violin Plot

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='NoOfBath',y='BuildingType',data=df,palette="Spectral",orient='h')
plt.subplot(2,2,2)
sns.violinplot(x='AreaSqFt',y='Location',data=df,palette="ocean",orient='h')
plt.subplot(2,2,3)
sns.violinplot(x='NoOfPeople',y='BuildingType',data=df,palette="YlOrBr",orient='h')
plt.subplot(2,2,4)
sns.violinplot(x='NoOfBalcony',y='Location',data=df,palette="ch:s=-.2,r=.6",orient='h')
# Out:
# <AxesSubplot:xlabel='NoOfBalcony', ylabel='Location'>

# %% [markdown]
# ## StripPlot

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.stripplot(x='AreaSqFt',y='BuildingType',data=df,jitter=True,edgecolor='black',orient='h')

plt.subplot(2,2,2)
sns.stripplot(x='NoOfBath',y='Location',data=df,jitter=True,edgecolor='black',orient='h')

plt.subplot(2,2,3)
sns.stripplot(x='NoOfBalcony',y='BuildingType',data=df,jitter=True,edgecolor='black',orient='h')

plt.subplot(2,2,4)
sns.stripplot(x='NoOfPeople',y='Location',data=df,jitter=True,edgecolor='black',orient='h')
# Out:
# <AxesSubplot:xlabel='NoOfPeople', ylabel='Location'>

# %% [markdown]
# ## SwarmPlot

# %%
ax = sns.swarmplot(x="AreaSqFt", y="Location", data=df,palette="viridis_r",orient='h')
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 77.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 85.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 86.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 82.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ## FacetGridPlot

# %%
sns.set_style("darkgrid")
sns.FacetGrid(df,hue="Location",height=4,palette="rocket_r") \
    .map(plt.scatter,"NoOfPeople","NoOfBath") \
    .add_legend()
plt.show()

# %% [markdown]
# ## HeatMap

# %%
plt.figure(figsize=(10,11))
sns.heatmap(df.corr(),annot=True,cmap="nipy_spectral")
plt.plot()
# Out:
# []

# %% [markdown]
# ## KDEPlot

# %%
sns.kdeplot(
    data=df, fill=True,thresh=0, levels=100,multiple="fill",palette="cubehelix_r"
)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## PieChart

# %%
df['Location'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.show()

# %%
df['BuildingType'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.show()

# %% [markdown]
# # -->Use the train_test_split method available in SCIKIT to split the dataset into Train Dataset and Test Dataset.
#
# # -->Show the Regression Score, Intercept and other parameters etc in the Output.

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
label_encoder=preprocessing.LabelEncoder()
df['BuildingType']=label_encoder.fit_transform(df['BuildingType'])
df['BuildingType'].unique()
df['Location']=label_encoder.fit_transform(df['Location'])
df['Location'].unique()
df['Size']=label_encoder.fit_transform(df['Size'])
df['Size'].unique()

X=df.drop('RentPerMonth',axis=1)
y=df.RentPerMonth
split_data=[]

# %%
r2_list=[]
r_intercept_list=[]
r_slope=[]
split_ratio=[]
y_p_list=[]
for i in range(50,81,10):
    a,b,c,d=train_test_split(X,y,train_size=i/100,random_state=0)
    split_data.append((a,b,c,d))
    model=LinearRegression().fit(a,c)
    y_predict=model.predict(b)
    y_p_list.append(y_predict)
    r2_list.append(r2_score(d,y_predict))
    r_intercept_list.append(model.intercept_)
    r_slope.append(model.coef_)
    split_ratio.append(f"{i}:{100-i}")

pos=r2_list.index(max(r2_list))

print("The maximum score got is in ratio",split_ratio[pos],"with the accuracy:",max(r2_list))
print("The intercept of the split ratio",split_ratio[pos],"is:",r_intercept_list[pos])
print("The slope of the split ratio",split_ratio[pos],"is:",r_slope[pos])

X_train,X_test,y_train,y_test=split_data[pos] #a,b,c,d for 60% training data
y_pred=y_p_list[pos]
# Out:
# The maximum score got is in ratio 60:40 with the accuracy: 0.7001911289467464
# The intercept of the split ratio 60:40 is: -11259.890688966794
# The slope of the split ratio 60:40 is: [ 4.07712088e+02 -1.00145165e+02 -7.16342821e+02  7.25981527e-01
#   2.77199376e+03  6.19306314e+03  2.62804770e+02]

# %%
X_train
# Out:
#      BuildingType  Location  Size  AreaSqFt  NoOfBath  NoOfPeople  NoOfBalcony
# 671             4         8     3    1740.0         2           2            0
# 109             5         1     2     750.0         2           1            1
# 661             1         3     2    1278.0         2           2            2
# 379             5         8     2    1460.0         2           2            1
# 625             4         2     2    1308.0         2           3            2
# ..            ...       ...   ...       ...       ...         ...          ...
# 835             6         0     3    1850.0         3           2            3
# 192             3         9     3    1075.0         2           1            1
# 629             1         4     4    1200.0         4           3            0
# 559             4         0     3    1650.0         3           2            2
# 684             4         0     4    2225.0         4           2            0
#
# [600 rows x 7 columns]

# %%
X_test
# Out:
#      BuildingType  Location  Size  AreaSqFt  NoOfBath  NoOfPeople  NoOfBalcony
# 993             9         6     3    4000.0         3           6            1
# 859             4         8     4    1200.0         4           3            3
# 298             5         2     2    1150.0         2           2            3
# 553             4         0     3    1400.0         3           2            0
# 672             1         3     4    1200.0         3           2            1
# ..            ...       ...   ...       ...       ...         ...          ...
# 81              5         0     2     861.0         2           1            1
# 159             5         4     2    1185.0         2           2            2
# 333             5         1     2    1166.0         2           2            2
# 837             6         0     7    1200.0         7           2            3
# 474             4         4     2    1246.0         2           2            1
#
# [400 rows x 7 columns]

# %%
y_train
# Out:
# 671     9500.0
# 109     3800.0
# 661     9500.0
# 379     5800.0
# 625     8904.0
#         ...
# 835    15000.0
# 192     4500.0
# 629     9000.0
# 559     7800.0
# 684     9888.0
# Name: RentPerMonth, Length: 600, dtype: float64

# %%
y_test
# Out:
# 993    66000.0
# 859    16500.0
# 298     5200.0
# 553     7700.0
# 672     9500.0
#         ...
# 81      3450.0
# 159     4260.0
# 333     5500.0
# 837    15000.0
# 474     6700.0
# Name: RentPerMonth, Length: 400, dtype: float64

# %% [markdown]
# # SECTION 3

# %% [markdown]
# # Questions
# # 1. What are your observations on the Dataset?
# # 2. What are the different Error Measures (Evaluation Metrics) in relation to Linear Regression? How much do you get in the above cases?
# # 3. Note down the errors/losses when the train-test ratio is 50:50, 60:40, 70:30, and 80:20
# # 4. During LinearRegression() process, what is the impact of giving TRUE/FALSE as the value for Normalize Parameter?

# %% [markdown]
# # 1.What are your observations on the Dataset?

# %% [markdown]
# ### The dataset talks about the rental houses in lavasa with different features. It has 1000 rows and 8 columns. The column names are BuildingType, Location, Size, AreaSqFt, NoOfBath, NoOfPeople, NoOfBalcony,RentPerMonth. The data is both numerixal as well as categorical.

# %% [markdown]
# ### The EDA part of the dataset shows the necessary details of the dataset with visualization but yes it contains seven independent variables and 1 dependent variable which is the House Rent which has to be predicted based on those seven independent features which are given in the dataset.

# %% [markdown]
# # 2.What are the different Error Measures (Evaluation Metrics) in relation to Linear Regression? How much do you get in the above cases?

# %% [markdown]
# # 3.Note down the errors/losses when the train-test ratio is 50:50, 60:40, 70:30, and 80:20

# %% [markdown]
# ## Mean Absolute Error

# %%
from sklearn.metrics import mean_absolute_error
for i in range(len(split_data)):
    mae_loss=mean_absolute_error(split_data[i][3], y_p_list[i])
    print("The Mean Absolute Error of",split_ratio[i],"ratio is:",mae_loss)
# Out:
# The Mean Absolute Error of 50:50 ratio is: 3860.404397984834
# The Mean Absolute Error of 60:40 ratio is: 3998.0193208486976
# The Mean Absolute Error of 70:30 ratio is: 4239.919647596396
# The Mean Absolute Error of 80:20 ratio is: 4261.778516976777

# %% [markdown]
# ## Mean Squared Error

# %%
from sklearn.metrics import mean_squared_error
for i in range(len(split_data)):
    mse_loss=mean_squared_error(split_data[i][3], y_p_list[i])
    print("Mean Squared Error of",split_ratio[i],"ratio is:",mse_loss)
# Out:
# Mean Squared Error of 50:50 ratio is: 40186685.791767366
# Mean Squared Error of 60:40 ratio is: 44751511.03094385
# Mean Squared Error of 70:30 ratio is: 55958259.933157556
# Mean Squared Error of 80:20 ratio is: 51319663.029937744

# %% [markdown]
# ## Mean Residual Error

# %%
from statistics import mean 
for i in range(len(split_data)):
    residual_error = split_data[i][3]-y_p_list[i]
    mean_r=mean(residual_error)
    print("Mean Residual Error of",split_ratio[i],"ratio is:",mean_r)
# Out:
# Mean Residual Error of 50:50 ratio is: 371.4832315323434
# Mean Residual Error of 60:40 ratio is: 362.6021289117355
# Mean Residual Error of 70:30 ratio is: 699.0344090963331
# Mean Residual Error of 80:20 ratio is: 612.3531159875663

# %% [markdown]
# ## Root Mean Squared Error

# %%
from math import sqrt
for i in range(len(split_data)):
    rmse_loss=sqrt(mean_squared_error(split_data[i][3], y_p_list[i]))
    print("Root Mean Squared Error of",split_ratio[i],"ratio is:",rmse_loss)
# Out:
# Root Mean Squared Error of 50:50 ratio is: 6339.296947751175
# Root Mean Squared Error of 60:40 ratio is: 6689.657018931826
# Root Mean Squared Error of 70:30 ratio is: 7480.525378150759
# Root Mean Squared Error of 80:20 ratio is: 7163.774356436538

# %% [markdown]
# # 4.During LinearRegression() process, what is the impact of giving TRUE/FALSE as the value for Normalize Parameter?

# %%
for i in range(len(split_data)):
    model=LinearRegression(normalize=True).fit(split_data[i][0],split_data[i][2])
    y_pred=model.predict(split_data[i][1])
    r_score=r2_score(split_data[i][3],y_pred)
    print("\nR_score of ",split_ratio[i]," when normalize is TRUE is: ",r_score)
    
    model=LinearRegression(normalize=False).fit(split_data[i][0],split_data[i][2])
    y_pred=model.predict(split_data[i][1])
    r_score=r2_score(split_data[i][3],y_pred)
    print("R_score of ",split_ratio[i]," when normalize is FALSE is: ",r_score)
# Out:
# R_score of  50:50  when normalize is TRUE is:  0.6991443910605246
# R_score of  50:50  when normalize is FALSE is:  0.6991443910605251
#
# R_score of  60:40  when normalize is TRUE is:  0.7001911289467468
# R_score of  60:40  when normalize is FALSE is:  0.7001911289467464
#
# R_score of  70:30  when normalize is TRUE is:  0.6877878340648071
# R_score of  70:30  when normalize is FALSE is:  0.687787834064807
#
# R_score of  80:20  when normalize is TRUE is:  0.6975571503047424
# R_score of  80:20  when normalize is FALSE is:  0.6975571503047422
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# ...

# %% [markdown]
# ### Hence, we could observe that normalize can be either True or False, it doesn't make any difference in the accuracy of the model. We could see that with separate split ratios.

# %% [markdown]
# # SECTION 4

# %% [markdown]
# # CASES:
# # Predicting the rent of the houses as per user input

# %%
values=('Minimum Budget Rooms-3','Semi Furnished Single Room-5','Semi Furnished Flat-4','Fully Furnished Single Room-1','Super Furnished Single Room-8','Semi Furnished Villa-6','Fully Furnished Flat-0','Super Furnished Flat-7','Fully Furnished Villa-2','Super Furnished Villa-9')
values1=['Portofino H-8','School Street-9','Portofino B-2','Portofino A-1','Clubview Road-0','Portofino C-3','Portofino D-4','Starter Homes-10','Portofino G-7','Portofino E-5','Portofino F-6']
values2=['1 BHK-->0','2 BHK-->2','1 RK-->1','3 BHK-->3','4 BHK-->4','5 BHK-->8','7 BHK-->7','9 BHK-->9']

# %%
df=pd.DataFrame(columns=["BuildingType","Location","Size","AreaSqFt","NoOfBath","NoOfPeople","NoOfBalcony"])

for i in range(1):
    for i in range(len(values)):
        print(values[i])
    bt=int(input("Enter the Prefereable Building Type:"))
    print("*"*50)
    
    for i in range(len(values1)):
        print(values1[i])
    loc=int(input("Enter the Prefereable Location:"))
    print("*"*50)
    
    for i in range(len(values2)):
        print(values2[i])
    size=int(input("Enter the Prefereable Size:"))
    print("*"*50)
    area=input("Enter the Prefereable Area Square Feet:")
    print("*"*50)
    NoB=input("Enter the Prefereable Number of Bathrooms:")
    print("*"*50)
    NoP=input("Enter the Prefereable Number of People:")
    print("*"*50)
    Nobal=input("Enter the Prefereable Number of Balcony:")
    print("*"*50)

data={"BuildingType":bt,"Location":loc,"Size":size,"AreaSqFt":area,"NoOfBath":NoB,"NoOfPeople":NoP,"NoOfBalcony":Nobal}
df=df.append(data,ignore_index=True)
                
df
# Out:
# Minimum Budget Rooms-3
# Semi Furnished Single Room-5
# Semi Furnished Flat-4
# Fully Furnished Single Room-1
# Super Furnished Single Room-8
# Semi Furnished Villa-6
# Fully Furnished Flat-0
# Super Furnished Flat-7
# Fully Furnished Villa-2
# Super Furnished Villa-9
# Enter the Prefereable Building Type:3
# **************************************************
# Portofino H-8
# School Street-9
# Portofino B-2
# Portofino A-1
# Clubview Road-0
# Portofino C-3
# Portofino D-4
# Starter Homes-10
# Portofino G-7
# Portofino E-5
# Portofino F-6
# Enter the Prefereable Location:9
# **************************************************
# 1 BHK-->0
# 2 BHK-->2
# 1 RK-->1
# 3 BHK-->3
# 4 BHK-->4
# 5 BHK-->8
# 7 BHK-->7
# 9 BHK-->9
# Enter the Prefereable Size:1
# **************************************************
# Enter the Prefereable Area Square Feet:4
# **************************************************
# Enter the Prefereable Number of Bathrooms:5
# ...

# %%
pre=model.predict(df)
print("The House Rent according to your requirement in Lavasa is:",pre)
# Out:
# The House Rent according to your requirement in Lavasa is: [20854.95264916]

# %% [markdown]
# # SECTION 5

# %% [markdown]
# # Conclusion:
# Concluding the lab:
# A model which could predict based on multiple regression came to be an exciting lab where learnt the model building a bit along with logic building and exploratory data analysis and visualization.

# %% [markdown]
# # SECTION 6

# %% [markdown]
# # Reference Links:
# 1. https://realpython.com/linear-regression-in-python/
# 2. https://www.kaggle.com/general/23263
# 3. https://www.analyticsvidhya.com/blog/2021/10/evaluation-metric-for-regression-models/
